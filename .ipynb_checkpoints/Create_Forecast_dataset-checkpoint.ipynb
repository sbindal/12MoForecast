# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime
from pandas_datareader import data
from datetime import datetime, timedelta
import requests
from bs4 import BeautifulSoup
import re
import json

# %%
def get_12Moforecast(tick):
    """
    Takes in a tick sign and date variable and gets the historical dividend dates for that tick symbal AFTER the data input.
    Outputs: dataframe with these columns:
    'exOrEffDate', 'type', 'amount', 'declarationDate', 'recordDate','paymentDate', 'Tick'
    """
    
    #need headers otherwise they will think you are a bot 
    headers = { "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
            "Upgrade-Insecure-Requests": "1",
            "User-Agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36 RuxitSynthetic/1.0 v7992529445 t38550 ath9b965f92 altpub cvcv=2"
        }

    url = "https://money.cnn.com/quote/forecast/forecast.html?symb={}".format(tick)
    response = requests.get(url,headers=headers)
    
    return response

# %%
def parse_12Moforecast(tick, response):

    html_text = response.text
    
    columnNames = ['tick', 'Analysts', 'Recommendation', 'Median', 'High', 'Low', 'Growth', 'Last']
    
    soup = BeautifulSoup(html_text, "html.parser")
    
    # find all div elements that are inside a div element
    # and are proceeded by an h3 element
    selector = 'div > h3 ~ div'
    
    divs = soup.select(selector)
    
    # Extract data from the found elements
    data = [x.text.split(';')[-1].strip() for x in divs]
    
    df = pd.DataFrame(columns = columnNames)

    for x in data:
        
        if (x.find("12-month price forecasts for") > 0):
            matches = re.findall(r'[\d\.\d]+', x)
            df.loc[1, 'Median'] = matches[2]
            df.loc[1, 'High'] = matches[3]
            df.loc[1, 'Low'] = matches[4]
            df.loc[1, 'Growth'] = matches[5]
            df.loc[1, 'Last'] = matches[6]
            
        if (x.startswith("The current consensus among") == 1):
            match = re.findall(r'[\d\.\d]+', x)    
            df.loc[1, 'Analysts'] = match[1]
            if (x.find('is to Hold stock') > 0):
                df.loc[1, 'Recommendation'] = 'Hold'
            if (x.find('is to Buy stock') > 0):
                df.loc[1, 'Recommendation'] = 'Buy'
            if (x.find('is to Sell stock') > 0):
                df.loc[1, 'Recommendation'] = 'Sell'


    
    df.loc[1, 'tick'] = tick
           
    return df

# %%
dfs = []
for stock in ['T','XOM','INFY','LUV','GRMN','UMC','CLX','HPQ','AMP', 'NIO', 'LI', 'BEST', 'TSLA', 'BIGC']:
    response = get_12Moforecast(stock)
    df = parse_12Moforecast(stock, response)
    dfs.append(df)

# %%
# Out:
# [  tick                              AnalystRecommendation  \
#  1    T  The current consensus among 28 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 5.12%      Growthannually...  ,
#    tick                              AnalystRecommendation  \
#  1  XOM  The current consensus among 26 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly -0.70%      Growthannuall...  ,
#     tick                              AnalystRecommendation  \
#  1  INFY  The current consensus among 50 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 3.29%      Growthannually...  ,
#    tick                              AnalystRecommendation  \
#  1  LUV  The current consensus among 23 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 19.43%      Growthannuall...  ,
#     tick                              AnalystRecommendation  \
#  1  GRMN  The current consensus among 9 polled investmen...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 6.26%      Growthannually...  ,
#    tick                              AnalystRecommendation  \
#  1  UMC  The current consensus among 24 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 1.31%      Growthannually...  ,
#    tick                              AnalystRecommendation  \
#  1  CLX  The current consensus among 16 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly -9.63%      Growthannuall...  ,
#    tick                              AnalystRecommendation  \
#  1  HPQ  The current consensus among 18 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly -1.58%      Growthannuall...  ,
#    tick                              AnalystRecommendation  \
#  1  AMP  The current consensus among 14 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 2.52%      Growthannually...  ,
#    tick                              AnalystRecommendation  \
#  1  NIO  The current consensus among 15 polled investme...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 44.38%      Growthannuall...  ,
#    tick                              AnalystRecommendation  \
#  1   LI  The current consensus among 11 polled investme...
#
#                                        StockForecast
#  1  SalesGrowthquarterly 44.31%    Growthannually --  ,
#     tick                              AnalystRecommendation  \
#  1  BEST  The current consensus among 8 polled investmen...
#
#                                         StockForecast
#  1  SalesGrowthquarterly 111.65%      Growthannual...  ]

# %%
result = pd.concat(dfs, ignore_index=True)
result.to_csv('12MoForecast.csv',index=False)
result
# Out:
#     tick Analysts Recommendation  Median    High      Low   Growth     Last
# 0      T        .           Hold   31.00   38.00   16.00.     4.10   29.78.
# 1    XOM        .           Hold   49.00   79.00   36.00.     8.70   45.08.
# 2   INFY        .            Buy   18.48   25.07   14.00.     5.98   17.44.
# 3    LUV        .            Buy   51.00   65.00   40.00.     7.17   47.59.
# 4   GRMN        .           Hold  120.00  124.00  105.00.     1.30  121.58.
# 5    UMC        .            Buy    7.68   10.68    4.46.     8.84    8.43.
# 6    CLX        .           Hold  225.00  268.00  174.00.    15.31  195.12.
# 7    HPQ        .           Hold   24.00   30.00   14.00.     5.47   25.39.
# 8    AMP        .            Buy  220.50  230.00  186.00.     9.66  201.07.
# 9    NIO        .            Buy  327.15  457.79   98.10.   511.50   53.50.
# 10    LI       ..            Buy       .  258.54   394.93  139.98.   654.41
# 11  BEST        .            Buy   23.00   39.43    9.70.        1   064.43
# 12  TSLA        .           Hold  440.00  810.00   40.00.    44.54  793.39.
# 13  BIGC       ..           Hold       .   90.00   132.00   57.00.    45.42
